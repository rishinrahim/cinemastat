# %% [markdown]
# # Data Collection
#
# Data is collected from mainly 2 sources :
# - https://www.malayalachalachithram.com/
# - https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_[year]
#
# Libraries used :
# - BeautifulSoup : a library that makes it easy to scrape information from web pages. https://pypi.org/project/beautifulsoup4/
# - html5lib :  a pure-python library for parsing HTML. https://pypi.org/project/html5lib/

# %%
#importing all libraries required

import requests
from bs4 import BeautifulSoup
import pandas as pd
import html5lib
import numpy as np
from datetime import datetime
import datefinder

# %%
def reprel(text):
    matches = datefinder.find_dates(text)
    for match in matches:
        s=match
        if s:
            return s.date()

    return text

# %%
df=[]
batch = 64
count = 0
for b in range(batch):
    print("====batch===",b+1)
    for i in range(b*100,(b+1)*100):
        count = count+1
        loc ="https://www.malayalachalachithram.com/movie.php?i="+str(i)
        url = requests.get(loc).text
        soup = BeautifulSoup(url,"lxml")
        try:
            table = soup.find("table",{"class":"mdetails"})
            name = soup.select('h1.movie')[0].text.strip()
            t =str(table)
            data = pd.read_html(t)[0]
            df1 = data.T    
            df1.columns = df1.iloc[0]
            df1.drop(df1.index[0],inplace=True)
            df1["Movie"] = name
#             cast = []
#             print(name)
#             divTag = soup.find_all("div", {"class": "heroes"})
#             if divTag:
#                 for tag in divTag:
#                     try:
#                         cast.append(tag.find("a").text)
#                     except:
#                         continue
#             try:
#                 tables = soup.findAll("table",{"class":"cast"})
#                 try:
#                     for a in tables:
#                         a = table.findAll(lambda tag: tag.name=='a')
#                         for c in a:
#                             cast.append(c.text)
#                 except:
#                     cast = []
#             except:
#                 continue

#             df1["cast"]=[cast]
            df1["new_status"] = df1.Status.apply(reprel)
            df.append(df1)
        except:
            continue
# Out:
# ====batch=== 1
# ====batch=== 2
# ====batch=== 3
# ====batch=== 4
# ====batch=== 5
# ====batch=== 6
# ====batch=== 7
# ====batch=== 8
# ====batch=== 9
# ====batch=== 10
# ====batch=== 11
# ====batch=== 12
# ====batch=== 13
# ====batch=== 14
# ====batch=== 15
# ====batch=== 16
# ====batch=== 17
# ====batch=== 18
# ====batch=== 19
# ====batch=== 20
# ====batch=== 21
# ====batch=== 22
# ====batch=== 23
# ====batch=== 24
# ====batch=== 25
# ====batch=== 26
# ====batch=== 27
# ====batch=== 28
# ====batch=== 29
# ====batch=== 30
# ====batch=== 31
# ====batch=== 32
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-73-030e8e972088>", line 9, in <module>
#     url = requests.get(loc).text
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 195, in __getattribute__
#     return getattr(getmod(), name)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 179, in getmod
#     x = importobj(modpath, None)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 69, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/pytest.py", line 13, in <module>
#     from _pytest.fixtures import fixture, yield_fixture
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 842, in <module>
#     class FixtureFunctionMarker(object):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 844, in FixtureFunctionMarker
#     params = attr.ib(convert=attr.converters.optional(tuple))
# TypeError: attrib() got an unexpected keyword argument 'convert'
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-73-030e8e972088>", line 9, in <module>
#     url = requests.get(loc).text
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2927, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1831, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1371, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1279, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 195, in __getattribute__
#     return getattr(getmod(), name)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 179, in getmod
#     x = importobj(modpath, None)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 69, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/pytest.py", line 13, in <module>
#     from _pytest.fixtures import fixture, yield_fixture
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 842, in <module>
#     class FixtureFunctionMarker(object):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 844, in FixtureFunctionMarker
#     params = attr.ib(convert=attr.converters.optional(tuple))
# TypeError: attrib() got an unexpected keyword argument 'convert'
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-73-030e8e972088>", line 9, in <module>
#     url = requests.get(loc).text
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2927, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1831, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1371, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1279, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 195, in __getattribute__
#     return getattr(getmod(), name)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 179, in getmod
#     x = importobj(modpath, None)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 69, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/pytest.py", line 13, in <module>
#     from _pytest.fixtures import fixture, yield_fixture
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 842, in <module>
#     class FixtureFunctionMarker(object):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 844, in FixtureFunctionMarker
#     params = attr.ib(convert=attr.converters.optional(tuple))
# TypeError: attrib() got an unexpected keyword argument 'convert'
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 302, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-73-030e8e972088>", line 9, in <module>
#     url = requests.get(loc).text
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2927, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1831, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1371, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1279, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 195, in __getattribute__
#     return getattr(getmod(), name)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 179, in getmod
#     x = importobj(modpath, None)
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 69, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/pytest.py", line 13, in <module>
#     from _pytest.fixtures import fixture, yield_fixture
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 842, in <module>
#     class FixtureFunctionMarker(object):
#   File "/Users/fauxcomrade/anaconda3/lib/python3.6/site-packages/_pytest/fixtures.py", line 844, in FixtureFunctionMarker
#     params = attr.ib(convert=attr.converters.optional(tuple))
# TypeError: attrib() got an unexpected keyword argument 'convert'
# ---------------------------------------------------------------------------
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1827                         # in the engines. This should return a list of strings.
# -> 1828                         stb = value._render_traceback_()
#    1829                     except Exception:
#
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2925             if result is not None:
#    2926                 result.error_in_exec = sys.exc_info()[1]
# -> 2927             self.showtraceback(running_compiled_code=True)
#    2928         else:
#    2929             outflag = False
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1829                     except Exception:
#    1830                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1831                                             value, tb, tb_offset=tb_offset)
#    1832
#    1833                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369         self.tb = tb
#    1370         return FormattedTB.structured_traceback(
# -> 1371             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1372
#    1373
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1277             # Verbose modes need a full traceback
#    1278             return VerboseTB.structured_traceback(
# -> 1279                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1280             )
#    1281         else:
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1138             exception = self.get_parts_of_chained_exception(evalue)
#    1139             if exception:
# -> 1140                 formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1141                 etype, evalue, etb = exception
#    1142             else:
#
# TypeError: must be str, not list

# %%
newdf=df[0]
for i in range(1,len(df)):
    newdf = newdf.append(df[i])

# %%
newdf.shape
# Out:
# (3119, 25)

# %%
newdf.new_status
# Out:
# 1    1928-07-11
# 1    1933-12-05
# 1    1938-01-19
# 1    1940-07-04
# 1    1941-08-17
# 1    1948-02-25
# 1    1949-01-14
# 1    1950-04-21
# 1    1950-08-17
# 1      Released
# 1    1950-08-24
# 1    1950-04-13
# 1    1950-02-15
# 1    1951-03-15
# 1    1951-05-18
# 1    1951-12-09
# 1    1951-05-17
# 1    1951-03-29
# 1    1951-09-06
# 1    Unreleased
# 1    Unreleased
# 1    Unreleased
# 1    1952-01-16
# 1    1952-12-24
# 1    1952-07-25
# 1    1952-08-17
# 1    1952-05-12
# 1    1952-08-22
# 1    1952-09-05
# 1    1952-03-21
#         ...
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1    1998-11-13
# 1      Released
# 1    Unreleased
# 1      Released
# 1      Released
# 1    1998-10-15
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1    1998-04-09
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1      Released
# 1    1998-04-17
# Name: new_status, Length: 3119, dtype: object

# %%
newdf.to_pickle("./cinemastat_data.pkl")`
# Out:
#   File "<ipython-input-79-4749ec60af15>", line 1
#     newdf.to_pickle("./cinemastat_data.pkl")`
#                                             ^
# SyntaxError: invalid syntax

# %%
## Merging Data

data1 = pd.read_pickle("./dataset/cinemastat_newdf.pkl")
data2 = pd.read_pickle("./dataset/_dataclean.pkl")
data_wiki = pd.read_pickle("./dataset/mdata.pkl")

# %%
data1["cast"] = data1["cast"].apply(set)
column_1 = data1.columns

# %%
data1 = data1.reset_index()
data1.head(2)
# Out:
#    index Art Direction Background Music                            Banner  \
# 0      1           NaN              NaN  Travancore National Pictures Ltd
# 1      1           NaN              NaN              Sree Rajeswari Films
#
#   Choreography Cinematography Costumes Design Dialogue   Director  \
# 0          NaN      JC Daniel      NaN    NaN      NaN  JC Daniel
# 1          NaN       PE Nayik      NaN    NaN      NaN     PV Rao
#
#                          ...                         Music Original Story  \
# 0                        ...                           NaN            NaN
# 1                        ...                           NaN            NaN
#
#        Producer Screenplay Shooting Location Singers Sound Design      Status  \
# 0     JC Daniel  JC Daniel               NaN     NaN          NaN  1928-07-11
# 1  R Sundararaj     PV Rao               NaN     NaN          NaN  1933-12-05
#
#              Story                                               cast
# 0        JC Daniel  {PK Rosy, Johnson, Travancore National Picture...
# 1  CV Raman Pillai  {R Sundararaj, PV Rao, A Devaraj, Sree Rajeswa...
#
# [2 rows x 26 columns]

# %%
data2.rename(columns ={"cast":"leadcast"},inplace = True)

# %%
#normalizing column names
columns = [i.lower() for i in data1.columns]
data1.columns = columns

#normalizing column names
columns = [i.lower() for i in data2.columns]
data2.columns = columns

# %%
data = pd.merge(data1,data2[['movie','leadcast']],on='movie', how='left')
data.shape
# Out:
# (6374, 27)

# %%
#ADDING YEAR to the column derived from the movie name.
import re
def get_year(text):
    pattern = re.compile(r"\((\d+)\)")
    year = ''.join(pattern.findall(text))
    try:
        if int(year)>2020:
            return "UNKNOWN"
        else:
            return int(year)
    except:
        return "UNKNOWN"
        

data["year"] = data.movie.apply(get_year)
data.head(2)
# Out:
#    index art direction background music                            banner  \
# 0      1           NaN              NaN  Travancore National Pictures Ltd
# 1      1           NaN              NaN              Sree Rajeswari Films
#
#   choreography cinematography costumes design dialogue   director  ...   \
# 0          NaN      JC Daniel      NaN    NaN      NaN  JC Daniel  ...
# 1          NaN       PE Nayik      NaN    NaN      NaN     PV Rao  ...
#
#        producer screenplay shooting location singers sound design      status  \
# 0     JC Daniel  JC Daniel               NaN     NaN          NaN  1928-07-11
# 1  R Sundararaj     PV Rao               NaN     NaN          NaN  1933-12-05
#
#              story                                               cast  \
# 0        JC Daniel  {PK Rosy, Johnson, Travancore National Picture...
# 1  CV Raman Pillai  {R Sundararaj, PV Rao, A Devaraj, Sree Rajeswa...
#
#                                             leadcast  year
# 0          [JC Daniel, Johnson, PK Rosy, Sunder Raj]  1928
# 1  [Pious, Padmini, AP Krishna Menon, Devaki Bhai...  1933
#
# [2 rows x 28 columns]

# %%
#Rearranging columns
ignore = ["Background Music",'shooting location','original story',"distribution"]
columns =['year','movie', 'movie genre','director', 'editing','producer','banner','screenplay',
          'music','art direction','choreography', 'cinematography', 'costumes', 
          'design', 'dialogue','lyrics', 'makeup',  'singers','story','leadcast','cast','status']
data = data[columns]
data.shape
# Out:
# (6374, 22)

# %%
#removing year with unknown release data / All are dubbed movies
data = data[data["year"] != "UNKNOWN" ]
data.shape
# Out:
# (6303, 22)

# %%
## Removing Duplicate rows

# %%
import collections
movie_names = data.movie.values
duplicate =[item for item, count in collections.Counter(movie_names).items() if count > 1]

## [1, 2, 5]

# %%
duplicate
# Out:
# ['Criminal (2012)', 'Final Round (2016)']

# %%
data = data[~data.movie.isin(duplicate)]
data.shape
# Out:
# (6295, 22)

# %%
#Removing paranthesis and year from movie name and normalizing movie name
data["movie"] = data["movie"].str.replace(r"\(.*\)","")
data["movie"] = data["movie"].str.lower()
data["movie"] = data["movie"].str.strip()
data.movie.head(2)
# Out:
# 0    vigathakumaaran
# 1    maarthandavarma
# Name: movie, dtype: object

# %%
#remove the movies with NaN director, NaN cast and status as in progress

# %%
data.isnull().sum()
# Out:
# year                 0
# movie                0
# movie genre       6009
# director           388
# editing           1941
# producer          2356
# banner            2307
# screenplay        1786
# music              485
# art direction     3225
# choreography      6168
# cinematography    1701
# costumes          5637
# design            4087
# dialogue          1953
# lyrics             705
# makeup            5557
# singers            955
# story             1861
# leadcast             3
# cast                 0
# status               0
# dtype: int64

# %%
def clean_leadcast(leadcast):
    if isinstance(leadcast, list):
        return int(len(leadcast))
    else:
        return 0
   
                
data["len_cast"] = data.cast.apply(len)
data["len_lead"] = data.leadcast.apply(clean_leadcast)

print(data.shape);data.head(3)
# Out:
# (6295, 24)
#    year            movie movie genre   director      editing      producer  \
# 0  1928  vigathakumaaran         NaN  JC Daniel          NaN     JC Daniel
# 1  1933  maarthandavarma         NaN     PV Rao    A Devaraj  R Sundararaj
# 2  1938            balan         NaN  S Nottani  PP Varghese   TR Sundaram
#
#                              banner                 screenplay  \
# 0  Travancore National Pictures Ltd                  JC Daniel
# 1              Sree Rajeswari Films                     PV Rao
# 2                   Modern Theatres  Muthukulam Raghavan Pilla
#
#                music art direction   ...                      dialogue  \
# 0                NaN           NaN   ...                           NaN
# 1                NaN           NaN   ...                           NaN
# 2  KK Aroor, Ibrahim           NaN   ...     Muthukulam Raghavan Pilla
#
#                       lyrics makeup  \
# 0                        NaN    NaN
# 1                        NaN    NaN
# 2  Muthukulam Raghavan Pilla    NaN
#
#                                              singers              story  \
# 0                                                NaN          JC Daniel
# 1                                                NaN    CV Raman Pillai
# 2  KK Aroor, Master Madanagopal, MK Kamalam, Pall...  A Sundaram Pillai
#
#                                             leadcast  \
# 0          [JC Daniel, Johnson, PK Rosy, Sunder Raj]
# 1  [Pious, Padmini, AP Krishna Menon, Devaki Bhai...
# 2           [Alleppey Vincent, MK Kamalam, KK Aroor]
#
#                                                 cast      status len_cast  \
# 0  {PK Rosy, Johnson, Travancore National Picture...  1928-07-11        5
# 1  {R Sundararaj, PV Rao, A Devaraj, Sree Rajeswa...  1933-12-05        6
# 2  {Ibrahim, PP Varghese, KK Aroor, Master Madana...  1938-01-19       14
#
#   len_lead
# 0        4
# 1        7
# 2        3
#
# [3 rows x 24 columns]

# %%
c1 = data.director.isnull()
c2 =data.len_lead == 0
c3 = data.status == "In progress"
movie_unreleased = data[c3]
movie_unreleased.shape
# Out:
# (3630, 24)

# %%
movie_unreleased.to_excel("movie_unreleased.xlsx")

# %%
c1 = movie_unreleased.director.isnull()
c2 =movie_unreleased.len_lead == 0
mu_c1 = movie_unreleased[c1]
mu_c1.shape
# Out:
# (368, 24)

# %%
mu_c12 = movie_unreleased[c1 & ~ c2]
mu_c12.shape
# Out:
# (71, 24)

# %%
mu_c12.shape
# Out:
# (297, 24)

# %%
mu_c12
# Out:
#       year                          movie movie genre director  \
# 198   1966                   kunjikkoonan         NaN      NaN
# 709   1976                     homakundam         NaN      NaN
# 1071  1979           eeswara jagadeeswara         NaN      NaN
# 1077  1979                 kaalee chakram         NaN      NaN
# 1279  1981         adharangal vithumpunnu         NaN      NaN
# 1460  1989             paavaadapraayathil         NaN      NaN
# 1537  1983                  father damien         NaN      NaN
# 1947  1986              oraayiram ormakal         NaN      NaN
# 2256  1989                      makayiram         NaN      NaN
# 2388  1990                        khalasi         NaN      NaN
# 2403  1990                       indhanam         NaN      NaN
# 2524  1991                    sheershakam         NaN      NaN
# 2720  1993                   saayanthanam         NaN      NaN
# 2727  1993      theeram thedunna thirakal         NaN      NaN
# 2800  1994                       socrates         NaN      NaN
# 2809  1994                    kadalpponnu         NaN      NaN
# 2867  1995                  the president         NaN      NaN
# 2958  1996                   super action         NaN      NaN
# 3432  2001                     chethaaram         NaN      NaN
# 3508  2002                         yaamam         NaN      NaN
# 3829  2016           collectorude bhaarya         NaN      NaN
# 3836  2006                     aadu thoma         NaN      NaN
# 4037  2008                glamour nagaram         NaN      NaN
# 4343  2002                    mohaswapnam         NaN      NaN
# 4345  1985                   agniyasthram         NaN      NaN
# 4419  1975              veendum vasantham         NaN      NaN
# 4558  2012                      khilaafat         NaN      NaN
# 4573  2012          meow meow karimpoocha         NaN      NaN
# 4578  2012                   bulbul maina         NaN      NaN
# 4579  2012                   bhadraasanam         NaN      NaN
# ...    ...                            ...         ...      ...
# 4707  2012                 platform no. 1         NaN      NaN
# 4761  2013                          raavu         NaN      NaN
# 4792  2013      otta oruthiyum shariyalla         NaN      NaN
# 4857  2013                   cold storage         NaN      NaN
# 4882  2013                       yodhaavu         NaN      NaN
# 4903  2014                        baadsha         NaN      NaN
# 4908  2014              good bye december         NaN      NaN
# 4910  2014                   lasagu usaga         NaN      NaN
# 4941  2013                          gypsy         NaN      NaN
# 5035  2013                         brinda         NaN      NaN
# 5046  2009                         indian         NaN      NaN
# 5151  2015              life full of life         NaN      NaN
# 5214  2013                         june r         NaN      NaN
# 5271  2016             the beautiful game         NaN      NaN
# 5361  2016                         lahala         NaN      NaN
# 5370  2016                   panjaakshari         NaN      NaN
# 5374  2016           pradhaana vaarthakal         NaN      NaN
# 5456  2017          aanenkilum allenkilum         NaN      NaN
# 5629  2017                  puthiya yugam         NaN      NaN
# 5692  2018                   corner stone         NaN      NaN
# 5734  2018                   thani oruvan         NaN      NaN
# 5735  2018                    vikram veda         NaN      NaN
# 5859  2018  oru naadan mullappoo viplavam         NaN      NaN
# 5881  2018                     dairy milk         NaN      NaN
# 5899  2016                          bogan         NaN      NaN
# 5904  2015               yennai arinthaal         NaN      NaN
# 5923  2013                    120 minutes         NaN      NaN
# 5964  2016                anthyakoodaasha         NaN      NaN
# 6024  2019  jayante maranam oru flashback         NaN      NaN
# 6177  2017           dhruvaraja jagannadh         NaN      NaN
#
#                   editing                                           producer  \
# 198                   NaN                                                NaN
# 709                   NaN                                                NaN
# 1071                  NaN                                                NaN
# 1077                  NaN                                                NaN
# 1279                  NaN                                                NaN
# 1460            A Ramesan                                                NaN
# 1537                  NaN                                                NaN
# 1947                  NaN                                                NaN
# 2256                  NaN                                                NaN
# 2388                  NaN                                                NaN
# 2403                  NaN                                                NaN
# 2524                  NaN                                                NaN
# 2720                  NaN                                                NaN
# 2727                  NaN                                                NaN
# 2800                  NaN                                                NaN
# 2809                  NaN                                                NaN
# 2867                  NaN                                                NaN
# 2958                  NaN                                                NaN
# 3432                  NaN                                                NaN
# 3508               C Mani                                           D Sajith
# 3829                  NaN                                                NaN
# 3836                  NaN                                                NaN
# 4037          Gowtham Raj                                      Johnny Thomas
# 4343           DSR Subash                                                NaN
# 4345                  NaN                                                NaN
# 4419                  NaN                                        RM Subbayya
# 4558                  NaN                                                NaN
# 4573                  NaN                                      Mammy Century
# 4578        Ajay Devaloka                                                NaN
# 4579                  NaN                                       Sajith Kumar
# ...                   ...                                                ...
# 4707                  NaN                                                NaN
# 4761                  NaN                                       Vinu Abraham
# 4792                  NaN                                                NaN
# 4857                  NaN                                                NaN
# 4882                  NaN                                                NaN
# 4903                  NaN                                                NaN
# 4908                  NaN                                                NaN
# 4910                  NaN                                                NaN
# 4941                  NaN                                                NaN
# 5035                  NaN                                                NaN
# 5046  B Lenin, VT Vijayan                                         AM Rathnam
# 5151                  NaN                                       Siju Edappal
# 5214                  NaN                                           A Ansari
# 5271                  NaN  Asif Ali, Sajin Jaffer, Brijesh Muhammad, Ajay...
# 5361                  NaN                                                NaN
# 5370                  NaN                                                NaN
# 5374                  NaN                                                NaN
# 5456       Noufal Abdulla                                      Raju Malliath
# 5629                  NaN                                                NaN
# 5692                  NaN                                                NaN
# 5734                  NaN                                                NaN
# 5735                  NaN                                                NaN
# 5859                  NaN                                                NaN
# 5881                  NaN                                                NaN
# 5899                  NaN                                                NaN
# 5904                  NaN                                                NaN
# 5923                  NaN                                                NaN
# 5964                  NaN                                                NaN
# 6024                  NaN                                                NaN
# 6177                  NaN                                                NaN
#
#                      banner          screenplay                    music  \
# 198                     NaN                 NaN        BA Chidambaranath
# 709                     NaN                 NaN        V Dakshinamoorthy
# 1071                    NaN                 NaN              Raghu Kumar
# 1077                    NaN                 NaN        Kodakara Madhavan
# 1279                    NaN                 NaN               PS Divakar
# 1460                    NaN                 NaN           Murali Sithara
# 1537                    NaN                 NaN          Patrick Periera
# 1947                    NaN                 NaN               Raveendran
# 2256                    NaN                 NaN         Nedungad Vijayan
# 2388                    NaN                 NaN                  Johnson
# 2403                    NaN                 NaN            Jerson Antony
# 2524                    NaN                 NaN           Bombay S Kamal
# 2720                    NaN                 NaN             SP Venkitesh
# 2727                    NaN                 NaN              G Devarajan
# 2800                    NaN                 NaN               Raveendran
# 2809                    NaN                 NaN             Kannur Rajan
# 2867                    NaN                 NaN               Raveendran
# 2958           Choice Films                 NaN                      NaN
# 3432                    NaN                 NaN            Mohan Sithara
# 3508      Ranjith Creations                Sree             SP Bhoopathi
# 3829                    NaN                 NaN                   Chinna
# 3836                    NaN                 NaN              Josi Pullad
# 4037          Cochin Movies             Swamiji                   Chakri
# 4343                    NaN                 NaN                      NaN
# 4345                    NaN                 NaN                    Shyam
# 4419           RMS Pictures                 NaN              Raghavendra
# 4558                    NaN                 NaN                      NaN
# 4573                    NaN                 NaN           Shafeeq Rahman
# 4578                    NaN                 NaN              Gopi Sundar
# 4579  Pallavi International  Sunil Parameswaran                      NaN
# ...                     ...                 ...                      ...
# 4707   Shan Entertaintments                 NaN                      NaN
# 4761                    NaN                 NaN                      NaN
# 4792                    NaN                 NaN                      NaN
# 4857                    NaN                 NaN                 Arun Raj
# 4882                    NaN                 NaN              Mani Sharma
# 4903                    NaN                 NaN                 S Thaman
# 4908                    NaN                 NaN   Shillong Chamber Choir
# 4910                    NaN                 NaN           Sudeep Palanad
# 4941                    NaN                 NaN         Hamsa Kunnatheri
# 5035                    NaN                 NaN         KM Radhakrishnan
# 5046                    NaN                 NaN                AR Rahman
# 5151                    NaN        Mani Shornur            Mohan Sithara
# 5214                    NaN                 NaN                 Sharreth
# 5271                    NaN                 NaN                      NaN
# 5361                    NaN                 NaN                 S Thaman
# 5370                    NaN                 NaN                   Chinna
# 5374                    NaN                 NaN            Yash Krishnan
# 5456                    NaN                 NaN                      NaN
# 5629                    NaN                 NaN                      NaN
# 5692                    NaN                 NaN  KJ Jose, Gautham Rangan
# 5734                    NaN                 NaN          Hiphop Tamizhan
# 5735                    NaN                 NaN                  Sam C S
# 5859                    NaN                 NaN             Ameen Yassir
# 5881                    NaN                 NaN                      NaN
# 5899                    NaN                 NaN                  D Imman
# 5904                    NaN                 NaN           Harris Jayaraj
# 5923                    NaN                 NaN                   Kannan
# 5964                    NaN                 NaN          Kiran Anilkumar
# 6024                    NaN                 NaN                      NaN
# 6177                    NaN                 NaN          Devi Sri Prasad
#
#             art direction   ...                    dialogue  \
# 198                   NaN   ...                         NaN
# 709                   NaN   ...                         NaN
# 1071                  NaN   ...                         NaN
# 1077                  NaN   ...                         NaN
# 1279                  NaN   ...                         NaN
# 1460                  NaN   ...                         NaN
# 1537                  NaN   ...                         NaN
# 1947                  NaN   ...                         NaN
# 2256                  NaN   ...                         NaN
# 2388                  NaN   ...                         NaN
# 2403                  NaN   ...                         NaN
# 2524                  NaN   ...                         NaN
# 2720                  NaN   ...                         NaN
# 2727                  NaN   ...                         NaN
# 2800                  NaN   ...                         NaN
# 2809                  NaN   ...                         NaN
# 2867                  NaN   ...                         NaN
# 2958                  NaN   ...                         NaN
# 3432                  NaN   ...                         NaN
# 3508             Santhosh   ...                        Sree
# 3829                  NaN   ...                         NaN
# 3836                  NaN   ...                         NaN
# 4037                  NaN   ...     Mankombu Gopalakrishnan
# 4343                  NaN   ...                         NaN
# 4345                  NaN   ...                         NaN
# 4419                  NaN   ...                   Abhayadev
# 4558                  NaN   ...                         NaN
# 4573  Milton Perumbadappu   ...                         NaN
# 4578          Manu Jagath   ...                         NaN
# 4579                  NaN   ...          Sunil Parameswaran
# ...                   ...   ...                         ...
# 4707                  NaN   ...                         NaN
# 4761                  NaN   ...                         NaN
# 4792                  NaN   ...                         NaN
# 4857                  NaN   ...                         NaN
# 4882                  NaN   ...                         NaN
# 4903                  NaN   ...                         NaN
# 4908                  NaN   ...                         NaN
# 4910                  NaN   ...                         NaN
# 4941                  NaN   ...                         NaN
# 5035                  NaN   ...                         NaN
# 5046                  NaN   ...     Mankombu Gopalakrishnan
# 5151                  NaN   ...                         NaN
# 5214                  NaN   ...                         NaN
# 5271                  NaN   ...                         NaN
# 5361                  NaN   ...                         NaN
# 5370                  NaN   ...                         NaN
# 5374                  NaN   ...                         NaN
# 5456      Prasanth Madhav   ...                         NaN
# 5629                  NaN   ...                         NaN
# 5692                  NaN   ...                         NaN
# 5734                  NaN   ...                         NaN
# 5735                  NaN   ...                         NaN
# 5859                  NaN   ...                         NaN
# 5881                  NaN   ...                         NaN
# 5899                  NaN   ...                         NaN
# 5904                  NaN   ...                         NaN
# 5923                  NaN   ...                         NaN
# 5964                  NaN   ...                         NaN
# 6024                  NaN   ...                         NaN
# 6177                  NaN   ...                         NaN
#
#                                                  lyrics makeup  \
# 198                                         P Bhaskaran    NaN
# 709                          Appan Thachethu, Sathidevi    NaN
# 1071                                            Jayaraj    NaN
# 1077                                         GK Pallath    NaN
# 1279                                       T Thankappan    NaN
# 1460                              Vayalar Madhavankutty    NaN
# 1537                                    Patrick Periera    NaN
# 1947                                 Vellanad Narayanan    NaN
# 2256                                           SN Sarma    NaN
# 2388                                        K Jayakumar    NaN
# 2403                                      Chittoor Gopi    NaN
# 2524                                Vikram C Vanchiyoor    NaN
# 2720                                 Sreekumaran Thampi    NaN
# 2727                          Perumpuzha Gopalakrishnan    NaN
# 2800                            Mankombu Gopalakrishnan    NaN
# 2809                                   V Gopalakrishnan    NaN
# 2867                                Gireesh Puthenchery    NaN
# 2958                                                NaN    NaN
# 3432                                Gireesh Puthenchery    NaN
# 3508                                               Sree    NaN
# 3829                                Samji Aaraattupuzha    NaN
# 3836  Sudhamsu, George Puthankurish, Saji Vanchimala...    NaN
# 4037                                     Siju Thuravoor    NaN
# 4343                                                NaN    NaN
# 4345                                   Poovachal Khader    NaN
# 4419                                 Sreekumaran Thampi    NaN
# 4558                                                NaN    NaN
# 4573               Dinanath Puthenchery, Shafeeq Rahman    NaN
# 4578                                         Kaithapram    NaN
# 4579                                                NaN    NaN
# ...                                                 ...    ...
# 4707                                                NaN    NaN
# 4761                                                NaN    NaN
# 4792                                                NaN    NaN
# 4857  Harikrishna Kelakam, Jayan Thirumana, Sreemang...    NaN
# 4882                                     Siju Thuravoor    NaN
# 4903                                       Rafi Mathira    NaN
# 4908                                     Santhosh Varma    NaN
# 4910                                     Sasikala Menon    NaN
# 4941  Vayalar Sarathchandra Varma, Hamsa Kunnatheri,...    NaN
# 5035                                                NaN    NaN
# 5046                            Mankombu Gopalakrishnan    NaN
# 5151                    Chunakkara Ramankutty, KJ Singh    NaN
# 5214                                                NaN    NaN
# 5271                                                NaN    NaN
# 5361                                       Kailas Rishi    NaN
# 5370                                       Kailas Rishi    NaN
# 5374                                                Gee    NaN
# 5456                                                NaN    NaN
# 5629                                                NaN    NaN
# 5692                                                NaN    NaN
# 5734                                                NaN    NaN
# 5735                                                NaN    NaN
# 5859                          Ajeesh Dasan, AR Vadikkal    NaN
# 5881                                                NaN    NaN
# 5899                                                NaN    NaN
# 5904                                                NaN    NaN
# 5923                                        Azees Dasan    NaN
# 5964                                    Kiran Anilkumar    NaN
# 6024                                                NaN    NaN
# 6177                                     Siju Thuravoor    NaN
#
#                                                 singers               story  \
# 198         KJ Yesudas, P Jayachandran, P Leela, Renuka                 NaN
# 709                 KJ Yesudas, P Susheela, Vani Jairam                 NaN
# 1071                                     P Jayachandran                 NaN
# 1077     KJ Yesudas, P Susheela, P Madhuri, Vani Jairam                 NaN
# 1279  KJ Yesudas, LR Eeswari, Ambili, LR Anjali, Sre...                 NaN
# 1460                                         KJ Yesudas                 NaN
# 1537                            Simon, Supriya, Clement                 NaN
# 1947                        P Jayachandran, Vani Jairam                 NaN
# 2256                        MG Sreekumar, Sujatha Mohan                 NaN
# 2388                           KS Chithra, MG Sreekumar                 NaN
# 2403                KS Chithra, G Venugopal, Unni Menon                 NaN
# 2524                                         KJ Yesudas                 NaN
# 2720                             KJ Yesudas, KS Chithra                 NaN
# 2727  P Jayachandran, G Venugopal, Biju Narayanan, S...                 NaN
# 2800  KJ Yesudas, KS Chithra, P Mohanlal, Ranjini Menon                 NaN
# 2809  Unni Menon, Krishnachandran, Minmini, Malgudi ...                 NaN
# 2867  KS Chithra, MG Sreekumar, Sreenivas, Chintu, Fabi                 NaN
# 2958                                                NaN                 NaN
# 3432  KJ Yesudas, KS Chithra, S Janaki, MG Sreekumar...                 NaN
# 3508                                                NaN                Sree
# 3829                                          Sreevidya                 NaN
# 3836  MG Sreekumar, Sujatha Mohan, Biju Narayanan, M...                 NaN
# 4037                       Jyotsna, Afsal, Ranjini Jose             Swamiji
# 4343                                                NaN                 NaN
# 4345    S Janaki, Jency, Krishnachandran, Sherin Peters                 NaN
# 4419             KJ Yesudas, P Susheela, P Jayachandran                 NaN
# 4558                                                NaN           P Valsala
# 4573  Madhu Balakrishnan, Anupama Vijay, Rajalakshmi...                 NaN
# 4578                                                NaN                 NaN
# 4579                                                NaN  Sunil Parameswaran
# ...                                                 ...                 ...
# 4707                                                NaN                 NaN
# 4761                                                NaN                 NaN
# 4792                                                NaN                 NaN
# 4857            Arun Raj, Lakshmi Jayan, Aswathi Ramesh                 NaN
# 4882                                                NaN                 NaN
# 4903  Geethu, Shyam Shiva, Praveen V Dev, Shyama Sij...                 NaN
# 4908                             Shillong Chamber Choir                 NaN
# 4910                                                NaN                 NaN
# 4941  Ranjini Jose, Bimal Pankaj, Sheeja, Sreepriya,...                 NaN
# 5035                                                NaN                 NaN
# 5046  Madhu Balakrishnan, Jyotsna, Cicily, V Devanan...                 NaN
# 5151  Manikandan, Najim Arshad, Jisha Naveen, Poorna...                 NaN
# 5214                                             Anjana                 NaN
# 5271                                                NaN                 NaN
# 5361                                                NaN                 NaN
# 5370                                                NaN                 NaN
# 5374                    Sri Vallabhan, Sunita, Vanisree                 NaN
# 5456                                                NaN                 NaN
# 5629                                                NaN                 NaN
# 5692                                                NaN                 NaN
# 5734                                                NaN                 NaN
# 5735                                                NaN                 NaN
# 5859                           Rahana, Suresh Cherukode                 NaN
# 5881                                                NaN                 NaN
# 5899                                                NaN                 NaN
# 5904                                                NaN                 NaN
# 5923                                              Afsal                 NaN
# 5964                                       Arpith Kumar                 NaN
# 6024                                                NaN                 NaN
# 6177  Madhu Balakrishnan, Anwar Sadath, Rajalakshmi ...                 NaN
#
#                                                leadcast  \
# 198                                    [Master Vijayan]
# 709                                   [Shanthi Krishna]
# 1071                [Raghavan, Adoor Bhavani, MG Soman]
# 1077                                     [Geedha Salam]
# 1279                                         [MG Soman]
# 1460                  [Vinod Raj, Heera, Mamatha (New)]
# 1537  [Ratheesh, Ambika , Kunchan, Kuthiravattam Pap...
# 1947                                      [Jose, Seema]
# 2256              [Niyaz Musaliyar, Vettukkili Prakash]
# 2388                 [Adoor Bhasi, Kuthiravattam Pappu]
# 2403                           [Sathar, Mala Aravindan]
# 2524                                          [Ambika ]
# 2720                                          [Ambika ]
# 2727                             [Mukesh, Shobha Mohan]
# 2800                                    [Manoj K Jayan]
# 2809                                   [Vijayaraghavan]
# 2867                              [Kalabhavan Santhosh]
# 2958                          [Bhanupriya, Chiranjeevi]
# 3432                    [Ashokan, Mayoori, Meghanadhan]
# 3508  [Noushad, Bhaskar, Roshni , Gandhi, Maria, NK ...
# 3829                     [Bhoomika Chawla, Prakash Raj]
# 3836                                       [Juby Ninan]
# 4037  [Kalabhavan Mani, Sreekanth, Kaveri Jha, Manis...
# 4343                                [Shakkeela, Reshma]
# 4345                               [Sukumaran, Ambika ]
# 4419  [Akkineni Nageswara Rao, Manjula Vijayakumar, ...
# 4558                                    [Manoj K Jayan]
# 4573  [Kochu Preman, Kalabhavan Haneef, Suraj Venjar...
# 4578                        [Indrajith, Rima Kallingal]
# 4579                       [Prithviraj, Kavya Madhavan]
# ...                                                 ...
# 4707  [Jagathy Sreekumar, Innocent, Suraj Venjaramoo...
# 4761        [Ajith Ravi Pegasus, Sanam Prasad, Manasy ]
# 4792                                  [Ranjini Haridas]
# 4857                                      [Divyaprabha]
# 4882                                    [Kajal Agarwal]
# 4903                                    [Kajal Agarwal]
# 4908                                         [Asif Ali]
# 4910                                     [Kavya Suresh]
# 4941  [Geetha Vijayan, Kanakalatha, Salim Kumar, Salin]
# 5035                            [Raai Laxmi, Sreekanth]
# 5046                     [Kamalahasan, Manisha Koirala]
# 5151                                            [Devan]
# 5214                                  [Jyothika, Surya]
# 5271                             [Prithviraj, Asif Ali]
# 5361                        [Anushka Shetty, Nagarjuna]
# 5370                                   [Anushka Shetty]
# 5374                                           [Charmi]
# 5456       [Catherine Tressa, Fahad Fazil, Sunny Wayne]
# 5629                                            [Devan]
# 5692                                 [Pradeep Kottayam]
# 5734                           [Nayanthara, Jayam Ravi]
# 5735                                       [R Madhavan]
# 5859                                  [N Jayakrishnan ]
# 5881  [KPAC Lalitha, Baiju Ezhupunna, Karamana Sudhe...
# 5899                        [Aravind Swamy, Jayam Ravi]
# 5904                                      [Ajith Kumar]
# 5923                                  [Kalabhavan Mani]
# 5964                                   [Saritha S Nair]
# 6024                                    [Ponnamma Babu]
# 6177                                       [Allu Arjun]
#
#                                                    cast       status len_cast  \
# 198   {P Leela, BA Chidambaranath, P Bhaskaran, P Ja...  In progress        7
# 709   {Appan Thachethu, Vani Jairam, P Susheela, KJ ...  In progress        6
# 1071             {P Jayachandran, Jayaraj, Raghu Kumar}  In progress        3
# 1077  {Kodakara Madhavan, Vani Jairam, P Susheela, P...  In progress        6
# 1279  {Ambili, Sreekanth, MG Soman, T Thankappan, KJ...  In progress        8
# 1460  {Vayalar Madhavankutty, ENC Nair, KJ Yesudas, ...  In progress        9
# 1537         {Simon, Supriya, Patrick Periera, Clement}  In progress        4
# 1947  {Vani Jairam, Raveendran, P Jayachandran, Vell...  In progress        4
# 2256  {MG Sreekumar, SN Sarma, Sujatha Mohan, Nedung...  In progress        4
# 2388   {K Jayakumar, KS Chithra, MG Sreekumar, Johnson}  In progress        4
# 2403  {KS Chithra, Chittoor Gopi, Jerson Antony, Unn...  In progress        5
# 2524  {Bombay S Kamal, KJ Yesudas, Vikram C Vanchiyoor}  In progress        3
# 2720  {Sreekumaran Thampi, SP Venkitesh, KS Chithra,...  In progress        4
# 2727  {Sivadarsana, Manoj Mannam, P Jayachandran, Bi...  In progress        7
# 2800  {Ranjini Menon, Mankombu Gopalakrishnan, KS Ch...  In progress        7
# 2809  {Kannur Rajan, V Gopalakrishnan, Krishnachandr...  In progress        6
# 2867  {Chintu, KS Chithra, MG Sreekumar, Fabi, Giree...  In progress        7
# 2958            {Chiranjeevi, Bhanupriya, Choice Films}  In progress        3
# 3432  {Sujatha Mohan, S Janaki, KS Chithra, Manisha ...  In progress       10
# 3508  {Vijaya Kumar, Sree, Santhosh, Ranjith Creatio...  In progress        7
# 3829  {Bhoomika Chawla, Chinna, Prakash Raj, Samji A...  In progress        5
# 3836  {Jose Idukula, Afsal, Sujatha Mohan, Shaji Ell...  In progress       19
# 4037  {Cochin Movies, Chakri, Afsal, Mankombu Gopala...  In progress       12
# 4343         {Venkitesh, Reshma, DSR Subash, Shakkeela}  In progress        4
# 4345  {Ambika , Jency, S Janaki, Krishnachandran, Sh...  In progress        8
# 4419  {Sreekumaran Thampi, RM Subbayya, P Jayachandr...  In progress       11
# 4558                         {P Valsala, Manoj K Jayan}  In progress        2
# 4573  {Bhama, Mammy Century, Shafeeq Rahman, KP Namb...  In progress       11
# 4578  {Rima Kallingal, Kaithapram, Indrajith, Manu J...  In progress        6
# 4579  {Prithviraj, Sajith Kumar, Kavya Madhavan, Pal...  In progress        5
# ...                                                 ...          ...      ...
# 4707                             {Shan Entertaintments}  In progress        1
# 4761        {Manasy , Sanam Prasad, Ajith Ravi Pegasus}  In progress        3
# 4792                                                 {}  In progress        0
# 4857  {Jayan Thirumana, Harikrishna Kelakam, Arun Ra...  In progress        6
# 4882       {Mani Sharma, Siju Thuravoor, Kajal Agarwal}  In progress        3
# 4903  {Joyce, S Thaman, Rafi Mathira, Shyama Siju, G...  In progress        8
# 4908  {Santhosh Varma, Asif Ali, Shillong Chamber Ch...  In progress        3
# 4910     {Sudeep Palanad, Kavya Suresh, Sasikala Menon}  In progress        3
# 4941  {Gayathri Rajeev, Falah Ali, Bimal Pankaj, KK ...  In progress       12
# 5035          {KM Radhakrishnan, Raai Laxmi, Sreekanth}  In progress        3
# 5046  {V Devanand, Manisha Koirala, Kester, VT Vijay...  In progress       15
# 5151  {Manikandan, Najim Arshad, KJ Singh, Chunakkar...  In progress       10
# 5214  {Sharreth, Jyothika, Surya, Anjana, Madhu Ambatt}  In progress        5
# 5271                             {Prithviraj, Asif Ali}  In progress        2
# 5361  {Anushka Shetty, Kailas Rishi, S Thaman, Nagar...  In progress        4
# 5370             {Chinna, Anushka Shetty, Kailas Rishi}  In progress        3
# 5374  {Vanisree, Gee, Sri Vallabhan, Yash Krishnan, ...  In progress        6
# 5456  {Catherine Tressa, Prasanth Madhav, Raju Malli...  In progress        6
# 5629                                                 {}  In progress        0
# 5692        {Pradeep Kottayam, Gautham Rangan, KJ Jose}  In progress        3
# 5734          {Nayanthara, Hiphop Tamizhan, Jayam Ravi}  In progress        3
# 5735                              {Sam C S, R Madhavan}  In progress        2
# 5859  {Ajeesh Dasan, Ameen Yassir, Suresh Cherukode,...  In progress        6
# 5881                                                 {}  In progress        0
# 5899               {Aravind Swamy, D Imman, Jayam Ravi}  In progress        3
# 5904                      {Ajith Kumar, Harris Jayaraj}  In progress        2
# 5923     {Azees Dasan, Kalabhavan Mani, Afsal, Kannan }  In progress        4
# 5964    {Arpith Kumar, Saritha S Nair, Kiran Anilkumar}  In progress        3
# 6024                                                 {}  In progress        0
# 6177  {Durga Viswanath, Allu Arjun, Anwar Sadath, Si...  In progress       10
#
#      len_lead
# 198         1
# 709         1
# 1071        3
# 1077        1
# 1279        1
# 1460        3
# 1537        5
# 1947        2
# 2256        2
# 2388        2
# 2403        2
# 2524        1
# 2720        1
# 2727        2
# 2800        1
# 2809        1
# 2867        1
# 2958        2
# 3432        3
# 3508        6
# 3829        2
# 3836        1
# 4037        4
# 4343        2
# 4345        2
# 4419        3
# 4558        1
# 4573        8
# 4578        2
# 4579        2
# ...       ...
# 4707        5
# 4761        3
# 4792        1
# 4857        1
# 4882        1
# 4903        1
# 4908        1
# 4910        1
# 4941        4
# 5035        2
# 5046        2
# 5151        1
# 5214        2
# 5271        2
# 5361        2
# 5370        1
# 5374        1
# 5456        3
# 5629        1
# 5692        1
# 5734        2
# 5735        1
# 5859        1
# 5881        5
# 5899        2
# 5904        1
# 5923        1
# 5964        1
# 6024        1
# 6177        1
#
# [71 rows x 24 columns]
