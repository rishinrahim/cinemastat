# %% [markdown]
# # Data Collection
#
# Data is collected from mainly 2 sources :
# - https://www.malayalachalachithram.com/
# - https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_[year]
#
# Libraries used :
# - BeautifulSoup : a library that makes it easy to scrape information from web pages. https://pypi.org/project/beautifulsoup4/
# - html5lib :  a pure-python library for parsing HTML. https://pypi.org/project/html5lib/

# %%
#importing all libraries required

import requests
from bs4 import BeautifulSoup
import pandas as pd
import html5lib
import numpy as np
from datetime import datetime
import datefinder

# %%
def reprel(text):
    matches = datefinder.find_dates(text)
    for match in matches:
        s=match
        if s:
            return s.date()

    return "In progress"

# %%
df=[]
batch = 64
count = 0
for b in range(batch):
    print("====batch===",b+1)
    for i in range(b*100,(b+1)*100):
        count = count+1
        if count>6368:
            break
        loc ="https://www.malayalachalachithram.com/movie.php?i="+str(i)
        url = requests.get(loc).text
        soup = BeautifulSoup(url,"lxml")
        try:
            table = soup.find("table",{"class":"mdetails"})
            name = soup.select('h1.movie')[0].text.strip()
            t =str(table)
            data = pd.read_html(t)[0]
            df1 = data.T    
            df1.columns = df1.iloc[0]
            df1.drop(df1.index[0],inplace=True)
            df1["Movie"] = name
            cast = []
            print(name)
            divTag = soup.find_all("div", {"class": "heroes"})
            if divTag:
                for tag in divTag:
                    try:
                        cast.append(tag.find("a").text)
                    except:
                        continue
            try:
                tables = soup.findAll("table",{"class":"cast"})
                try:
                    for a in tables:
                        a = table.findAll(lambda tag: tag.name=='a')
                        for c in a:
                            cast.append(c.text)
                except:
                    cast = []
            except:
                continue

            df1["cast"]=[cast]
            df1.Status = df1.Status.apply(reprel)
            df.append(df1)
        except:
            continue

# %%
newdf_ =df[0]
for i in range(1,len(df)):
    newdf = newdf.append(df[i])

# %%
newdf_.shape
# Out:
# (6267, 25)

# %%
newdf.to_pickle("./cinemastat_data.pkl")

# %%
## Merging Data

data1 = pd.read_pickle("./dataset/cinemastat_newdf.pkl")
data2 = pd.read_pickle("./dataset/_dataclean.pkl")

# %%
data1["cast"] = data1["cast"].apply(set)
column_1 = data1.columns

# %%
data1 = data1.reset_index()
data1.head(2)
# Out:
#    index Art Direction Background Music                            Banner  \
# 0      1           NaN              NaN  Travancore National Pictures Ltd
# 1      1           NaN              NaN              Sree Rajeswari Films
#
#   Choreography Cinematography Costumes Design Dialogue   Director  \
# 0          NaN      JC Daniel      NaN    NaN      NaN  JC Daniel
# 1          NaN       PE Nayik      NaN    NaN      NaN     PV Rao
#
#                          ...                         Music Original Story  \
# 0                        ...                           NaN            NaN
# 1                        ...                           NaN            NaN
#
#        Producer Screenplay Shooting Location Singers Sound Design      Status  \
# 0     JC Daniel  JC Daniel               NaN     NaN          NaN  1928-07-11
# 1  R Sundararaj     PV Rao               NaN     NaN          NaN  1933-12-05
#
#              Story                                               cast
# 0        JC Daniel  {Travancore National Pictures Ltd, Johnson, JC...
# 1  CV Raman Pillai  {CV Raman Pillai, Sree Rajeswari Films, R Sund...
#
# [2 rows x 26 columns]

# %%
data2.rename(columns ={"cast":"leadcast"},inplace = True)

# %%
#normalizing column names
columns = [i.lower() for i in data1.columns]
data1.columns = columns

#normalizing column names
columns = [i.lower() for i in data2.columns]
data2.columns = columns

# %%
data = pd.merge(data1,data2[['movie','leadcast']],on='movie', how='left')
data.shape

# %%
#ADDING YEAR to the column derived from the movie name.
import re
def get_year(text):
    pattern = re.compile(r"\((\d+)\)")
    year = ''.join(pattern.findall(text))
    try:
        if int(year)>2020:
            return "UNKNOWN"
        else:
            return int(year)
    except:
        return "UNKNOWN"
        

data["year"] = data.movie.apply(get_year)
data.head(2)
# Out:
#    index art direction background music                            banner  \
# 0      1           NaN              NaN  Travancore National Pictures Ltd
# 1      1           NaN              NaN              Sree Rajeswari Films
#
#   choreography cinematography costumes design dialogue   director  ...   \
# 0          NaN      JC Daniel      NaN    NaN      NaN  JC Daniel  ...
# 1          NaN       PE Nayik      NaN    NaN      NaN     PV Rao  ...
#
#        producer screenplay shooting location singers sound design      status  \
# 0     JC Daniel  JC Daniel               NaN     NaN          NaN  1928-07-11
# 1  R Sundararaj     PV Rao               NaN     NaN          NaN  1933-12-05
#
#              story                                               cast  \
# 0        JC Daniel  {Travancore National Pictures Ltd, Johnson, JC...
# 1  CV Raman Pillai  {CV Raman Pillai, Sree Rajeswari Films, R Sund...
#
#                                             leadcast  year
# 0          [JC Daniel, Johnson, PK Rosy, Sunder Raj]  1928
# 1  [Pious, Padmini, AP Krishna Menon, Devaki Bhai...  1933
#
# [2 rows x 28 columns]

# %%
#Rearranging columns
ignore = ["Background Music",'shooting location','original story',"distribution"]
columns =['year','movie', 'movie genre','director', 'editing','producer','banner','screenplay',
          'music','art direction','choreography', 'cinematography', 'costumes', 
          'design', 'dialogue','lyrics', 'makeup',  'singers','story','leadcast','cast','status']
data = data[columns]
data.shape
# Out:
# (6374, 22)

# %%
data.tail(5)
# Out:
#       year                     movie movie genre         director   editing  \
# 6369  2001  Aarodum Parayathe (2001)         NaN     Praveen Dutt       NaN
# 6370  2002   Aaradyam Parayum (2002)         NaN          Paulson  R Sekhar
# 6371  1999       Mimics Ghost (1999)      Comedy          Paulson       NaN
# 6372  1998           Minukkam (1998)         NaN       Sasi Mohan       NaN
# 6373  2011  Ee Abhaya Theeram (2011)         NaN  Alex Thankachan       NaN
#
#           producer banner             screenplay                   music  \
# 6369  Gireesh Nair    NaN         Venu Mahadevan                SR Mohan
# 6370    Minu Kumar    NaN        Babu Pallassery               Aadithyan
# 6371           NaN    NaN                    NaN                 Johnson
# 6372           NaN    NaN  Sidhique Thamarassery  KV Abutty, Chandrabose
# 6373           NaN    NaN        Alex Thankachan          R Somasekharan
#
#           art direction     ...                    costumes design  \
# 6369  Shibu Pazhanchira     ...                     Arafath    NaN
# 6370   Lakshman G Malam     ...       Velayudhan Keezhillam    NaN
# 6371   Balan Karumaloor     ...                 V Ankuswami    NaN
# 6372      Murali Beppur     ...                         NaN    NaN
# 6373                NaN     ...                         NaN    NaN
#
#                    dialogue                   lyrics  \
# 6369         Venu Mahadevan   Bharanikkavu Sivakumar
# 6370        Babu Pallassery          Bichu Thirumala
# 6371                    NaN  Mankombu Gopalakrishnan
# 6372  Sidhique Thamarassery      Gireesh Puthenchery
# 6373        Alex Thankachan   Bharanikkavu Sivakumar
#
#                                makeup  \
# 6369                              NaN
# 6370  Salim Kadakkal(Salim Nagarcoil)
# 6371                          CV Anil
# 6372                              NaN
# 6373                              NaN
#
#                                                 singers            story  \
# 6369                MG Sreekumar, Bhavana Radhakrishnan     Gireesh Nair
# 6370  KS Chithra, MG Sreekumar, Biju Narayanan, P Un...     Beena Kumari
# 6371                                                NaN              NaN
# 6372                                                NaN              NaN
# 6373  Bhavana Radhakrishnan, Vidhu Prathap, B Shobha...  Alex Thankachan
#
#                                                leadcast  \
# 6369  [Sindhu, Adoor Pankajam, Jayanand, Jose Pellis...
# 6370                                   [Gopika, Rakesh]
# 6371                            [Indulekha, Shaju K.S.]
# 6372                                                NaN
# 6373                                                NaN
#
#                                                    cast       status
# 6369  {Shibu Pazhanchira, Venu Mahadevan, Bharanikka...  In progress
# 6370  {Babu Pallassery, Salim Kadakkal(Salim Nagarco...  In progress
# 6371  {Indulekha, CV Anil, V Ankuswami, Johnson, Bal...  In progress
# 6372  {Gireesh Puthenchery, Sasi Mohan, Murali Beppu...  In progress
# 6373  {Shakkeela, R Somasekharan, Bharanikkavu Sivak...  In progress
#
# [5 rows x 22 columns]

# %%
movie_names = data.movie
len(movie_names)
# Out:
# 6374

# %%
movie_names = list(movie_names)
len(set(movie_names))
# Out:
# 6368

# %%
import collections
print([item for item, count in collections.Counter(movie_names).items() if count > 1])

## [1, 2, 5]
# Out:
# ['Criminal (2012)', 'Final Round (2016)']

# %%
data = data[~data.movie.isin(['Criminal (2012)', 'Final Round (2016)'])]

# %%
data.shape
# Out:
# (6366, 22)

# %%
#removing year with unknown release data / All are dubbed movies
data = data[data["year"] != "UNKNOWN" ]
data.shape
# Out:
# (6295, 22)

# %%
data.isnull().sum()
# Out:
# year                 0
# movie                0
# movie genre       6009
# director           388
# editing           1941
# producer          2356
# banner            2307
# screenplay        1786
# music              485
# art direction     3225
# choreography      6168
# cinematography    1701
# costumes          5637
# design            4087
# dialogue          1953
# lyrics             705
# makeup            5557
# singers            955
# story             1861
# leadcast             3
# cast                 0
# status               0
# dtype: int64

# %%
def clean_leadcast(leadcast):
    if isinstance(leadcast, list):
        return int(len(leadcast))
#     else:
#         print(leadcast)
   
                
data["len_cast"] = data.cast.apply(len)
data["len_lead"] = data.leadcast.apply(clean_leadcast)

data[["cast","leadcast"]][:2]
# Out:
# nan
# nan
# nan
#                                                 cast  \
# 0  {Travancore National Pictures Ltd, Johnson, JC...
# 1  {CV Raman Pillai, Sree Rajeswari Films, R Sund...
#
#                                             leadcast
# 0          [JC Daniel, Johnson, PK Rosy, Sunder Raj]
# 1  [Pious, Padmini, AP Krishna Menon, Devaki Bhai...

# %%
c1 = data.director.isnull()
c2 =data.len_lead == 0
data[c1 & c2]
# Out:
#       year                                 movie    movie genre director  \
# 1066  1979               Sneham Dukhamanu (1979)            NaN      NaN
# 1950  1986     Prakrithiyile Albhuthangal (1986)            NaN      NaN
# 3688  2004                    Marmajaalam (2004)            NaN      NaN
# 4355  2002                       Deeptham (2002)            NaN      NaN
# 4377  2013                   Kallan Kalli (2013)  Investigation      NaN
# 4555  2015                    Shabdarekha (2015)            NaN      NaN
# 4604  2012             Thaazhvaarakkaattu (2012)            NaN      NaN
# 4668  2007                         Thadha (2007)            NaN      NaN
# 4710  2012                         Sunday (2012)            NaN      NaN
# 4772  2013           Kaattu Paranja Kadha (2013)            NaN      NaN
# 4792  2013      Otta Oruthiyum Shariyalla (2013)            NaN      NaN
# 4814  2013                         Signal (2013)            NaN      NaN
# 5073  2014               Snehathinte Vila (2014)            NaN      NaN
# 5146  2012              English Vinglish  (2012)            NaN      NaN
# 5182  2014             Kerala Home Guards (2014)            NaN      NaN
# 5439  2016                   Thotti Shiva (2016)            NaN      NaN
# 5629  2017                  Puthiya Yugam (2017)            NaN      NaN
# 5881  2018                     Dairy Milk (2018)            NaN      NaN
# 6024  2019  Jayante Maranam Oru Flashback (2019)            NaN      NaN
#
#      editing producer banner screenplay music art direction   ...    design  \
# 1066     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 1950     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 3688     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4355     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4377     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4555     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4604     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4668     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4710     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4772     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4792     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 4814     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5073     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5146     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5182     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5439     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5629     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 5881     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
# 6024     NaN      NaN    NaN        NaN   NaN           NaN   ...       NaN
#
#      dialogue lyrics makeup singers story  \
# 1066      NaN    NaN    NaN     NaN   NaN
# 1950      NaN    NaN    NaN     NaN   NaN
# 3688      NaN    NaN    NaN     NaN   NaN
# 4355      NaN    NaN    NaN     NaN   NaN
# 4377      NaN    NaN    NaN     NaN   NaN
# 4555      NaN    NaN    NaN     NaN   NaN
# 4604      NaN    NaN    NaN     NaN   NaN
# 4668      NaN    NaN    NaN     NaN   NaN
# 4710      NaN    NaN    NaN     NaN   NaN
# 4772      NaN    NaN    NaN     NaN   NaN
# 4792      NaN    NaN    NaN     NaN   NaN
# 4814      NaN    NaN    NaN     NaN   NaN
# 5073      NaN    NaN    NaN     NaN   NaN
# 5146      NaN    NaN    NaN     NaN   NaN
# 5182      NaN    NaN    NaN     NaN   NaN
# 5439      NaN    NaN    NaN     NaN   NaN
# 5629      NaN    NaN    NaN     NaN   NaN
# 5881      NaN    NaN    NaN     NaN   NaN
# 6024      NaN    NaN    NaN     NaN   NaN
#
#                                                leadcast cast       status  \
# 1066                                                 []   {}  In progress
# 1950                                                 []   {}  In progress
# 3688                                                 []   {}  In progress
# 4355                                                 []   {}  In progress
# 4377                                                 []   {}  In progress
# 4555                                                 []   {}  In progress
# 4604  [Mamukkoya, Suraj Venjaramoodu, Geetha Vijayan...   {}  In progress
# 4668                                                 []   {}  In progress
# 4710                                                 []   {}  In progress
# 4772                                                 []   {}  In progress
# 4792                                  [Ranjini Haridas]   {}  In progress
# 4814                                                 []   {}  In progress
# 5073                                                 []   {}  In progress
# 5146                                                 []   {}   2012-09-14
# 5182                                                 []   {}   2014-08-22
# 5439                                                 []   {}  In progress
# 5629                                            [Devan]   {}  In progress
# 5881  [KPAC Lalitha, Baiju Ezhupunna, Karamana Sudhe...   {}  In progress
# 6024                                    [Ponnamma Babu]   {}  In progress
#
#      len_lead
# 1066        0
# 1950        0
# 3688        0
# 4355        0
# 4377        0
# 4555        0
# 4604        0
# 4668        0
# 4710        0
# 4772        0
# 4792        0
# 4814        0
# 5073        0
# 5146        0
# 5182        0
# 5439        0
# 5629        0
# 5881        0
# 6024        0
#
# [19 rows x 23 columns]
